# %%
# importing needed lubraries
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
from skimage import exposure,img_as_ubyte
from skimage.filters import gaussian
import pandas as pd
from skimage.restoration import denoise_tv_chambolle, denoise_nl_means

# %%
data_dir= 'M:\\ExDark\\ExDark'

# %%
categ_1= os.path.join(data_dir, 'Boat')

# %%
ex= os.path.join(categ_1, '2015_00654.jpg')

# %%
img= cv2.imread(ex)
plt.imshow(img)

# %%
x = cv2.convertScaleAbs(img, alpha=6, beta=70)
x= cv2.GaussianBlur(x, (5,5), 0)
x=sharpen_image(x)
plt.imshow(x)
